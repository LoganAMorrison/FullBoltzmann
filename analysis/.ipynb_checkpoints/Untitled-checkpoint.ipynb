# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("full_boltz_data.dat")
xs = data[:,0]
fs = data[:,1:]

# %%
fs[0].shape
# Out:
# (100,)

# %%
plt.figure(dpi=150)
for i in range(0, len(xs), 200):
    plt.plot(f[i])
